# %%
import pandas as pd
import numpy as np

week1 = pd.read_csv('nfl-big-data-bowl-2021/week1.csv')

# %%
week1 = week1.copy()

# %%
week1['time'] = pd.to_datetime(week1['time'], format='%Y-%m-%dT%H:%M:%S')

# %%
week1['time_diff'] = week1.groupby('displayName')['time'].diff()

# %%
week1['time_diff'][week1['time_diff'].isnull()] = pd.Timedelta(0)

week1['time_acc_s'] = week1.groupby('displayName')['time_diff'].transform(lambda x: x.map(lambda x: x.microseconds).cumsum()).div(1e6)
# Out:
# /var/folders/6v/8jcf0jcn7_vfm2q2r4tz44gh0000gn/T/ipykernel_91329/1821502825.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   week1['time_diff'][week1['time_diff'].isnull()] = pd.Timedelta(0)

# %%
plays = pd.read_csv('nfl-big-data-bowl-2021/plays.csv')

# %%
week1 = week1.merge(plays, on=['playId', 'gameId'])

# %%
week1.head()
# Out:
#                               time      x      y     s     a   dis       o  \
# 0 2018-09-07 01:07:14.599000+00:00  91.73  26.67  0.00  0.01  0.02  289.57
# 1 2018-09-07 01:07:14.599000+00:00  88.89  36.47  0.01  0.01  0.01  105.63
# 2 2018-09-07 01:07:14.599000+00:00  91.35  44.16  0.02  0.03  0.01  290.45
# 3 2018-09-07 01:07:14.599000+00:00  86.31  22.01  0.09  0.42  0.01   70.12
# 4 2018-09-07 01:07:14.599000+00:00  90.78  36.15  0.00  0.00  0.00  257.61
#
#       dir event      nflId  ... preSnapHomeScore  gameClock  \
# 0  240.93  None      310.0  ...              0.0   15:00:00
# 1   66.66  None    79848.0  ...              0.0   15:00:00
# 2   16.86  None  2495454.0  ...              0.0   15:00:00
# 3  168.91  None  2495613.0  ...              0.0   15:00:00
# 4  193.97  None  2533040.0  ...              0.0   15:00:00
#
#   absoluteYardlineNumber  penaltyCodes penaltyJerseyNumbers  passResult  \
# 0                   90.0           NaN                  NaN           C
# 1                   90.0           NaN                  NaN           C
# 2                   90.0           NaN                  NaN           C
# 3                   90.0           NaN                  NaN           C
# 4                   90.0           NaN                  NaN           C
#
#    offensePlayResult playResult       epa isDefensivePI
# 0                 10         10  0.261827         False
# 1                 10         10  0.261827         False
# 2                 10         10  0.261827         False
# 3                 10         10  0.261827         False
# 4                 10         10  0.261827         False
#
# [5 rows x 46 columns]

# %%
week1['yardline_100'] = week1['absoluteYardlineNumber'].copy()
week1['yardline_first'] = np.where(week1['yardline_100'].gt(week1['x'].max()),
                                  week1['yardline_100'].add(week1['yardsToGo']),
                                  week1['yardline_100'].sub(week1['yardsToGo']))

# %%
week1['yardsToGo']
# Out:
# 0         15
# 1         15
# 2         15
# 3         15
# 4         15
#           ..
# 986017     2
# 986018     2
# 986019     2
# 986020     2
# 986021     2
# Name: yardsToGo, Length: 986022, dtype: int64

# %%
import altair as alt

alt.themes.enable('fivethirtyeight')
df = week1[week1['playId'] == week1['playId'].min()].drop(['time', 'time_diff'], axis=1)

players = alt.Chart(df).encode(
    x=alt.X('x:Q', title="Yard Line", scale=alt.Scale(zero=True)),
    y=alt.Y('y:Q', axis=None),
    color=alt.Color('displayName:N', title='Player',
                    scale=alt.Scale(scheme='category10'))
).mark_line(width=20)

scrimmage = alt.Chart(df).encode(
    x=alt.X('yardline_100:Q')
).mark_rule(color='blue')

first = alt.Chart(df).encode(
    x=alt.X('yardline_first:Q')
).mark_rule(color='yellow')

# %%
((players + scrimmage + first)
 .configure_view(fill='#348C31', fillOpacity=0.7)
 .properties(height=55*6, width=100*6, title=alt.TitleParams('Routes on First Play', anchor='middle')))
# Out:
# alt.LayerChart(...)

# %%
week1['time_elapsed'] = week1.groupby('displayName')['time_acc_s'].cumsum()

# %%
week1['x_behind_line'] = np.where(week1.groupby(['nflId', 'playId'])['x'].transform(lambda x: x.iloc[0]).gt(week1['absoluteYardlineNumber']),
         week1['x'].rsub(week1['absoluteYardlineNumber']),
         week1['x'].sub(week1['absoluteYardlineNumber']))

# %% [markdown]
# **Inputs into route prediction:**
# 1. Categorical position of player
# 2. Formation (note: given in dataset, but predictive model needed for real-time)
# 3. Initial position of player relative to line and in general
# 4. Initial positions of all defensive players, subdivided by position
# 5. Line of scrimmage formatted as yards needed for touchdown
# 6. Yards needed for a first down
# 7. Time elapsed since beginning of play

# %%
starting_pos_count = week1.groupby(['gameId', 'playId', 'team', 'nflId'])['position'].first().reset_index().groupby(
    ['gameId', 'playId', 'team', 'position']
)['position'].apply(lambda x: x.cumsum()).rename({'position': 'position_num'}, axis=1)
starting_idx = week1.groupby(['gameId', 'playId', 'team', 'nflId']).first().reset_index()[['gameId', 'playId', 'team', 'nflId']]
starting_idx['position_num'] = starting_pos_count.values
week1_pos = week1.merge(starting_idx, on=['gameId', 'playId', 'team', 'nflId'])
week1_pos['position_num'] = week1_pos['position_num'].map(lambda x: x[:2] + str(len(x) // 2))

# %%
week1_pos['x_starting_behind_line'] = week1_pos.groupby(['gameId', 'playId', 'position'])['x_behind_line'].transform(lambda x: x.iloc[0])

# %%
week1_pos['x_starting'] = week1_pos.groupby(['gameId', 'playId', 'position'])['x'].transform(lambda x: x.iloc[0])
week1_pos['y_starting'] = week1_pos.groupby(['gameId', 'playId', 'position'])['y'].transform(lambda x: x.iloc[0])

# %%
week1_pos['yards_needed_touch'] = np.where(week1_pos['yardline_100'].gt(week1_pos['yardline_first']),
                                           week1_pos['yardline_100'],
                                           week1_pos['yardline_100'].rsub(100))

# %%
off_def = (week1_pos
           .groupby(['gameId', 'playId', 'team'])['position']
           .apply(lambda x: 'QB' in x.unique() or 'WR' in x.unique())
           .reset_index()
           .rename({'position': 'off'}, axis=1)
           )

# %%
week1_off_def = week1_pos.merge(off_def, on=['gameId', 'playId', 'team'])

# %%
week1_def = week1_off_def[week1_off_def['off'] == False]
week1_off = week1_off_def[week1_off_def['off'] == True]

# %%
week1_def_starting = (week1_def
 .pivot_table(
    columns='position_num',
    values=['x_starting', 'x_starting_behind_line', 'y_starting'],
    index=['gameId', 'playId']))

# %%
week1_def_starting_cols = ['_'.join(x) for x in week1_def_starting.columns]
week1_def_starting.columns = week1_def_starting_cols

# %%
week1_def_starting.reset_index(inplace=True)

# %%
week1_off_starting = week1_off.merge(week1_def_starting, on=['gameId', 'playId'])

# %%
week1_off_starting.columns
# Out:
# Index(['time', 'x', 'y', 's', 'a', 'dis', 'o', 'dir', 'event', 'nflId',
#        ...
#        'y_starting_NT1', 'y_starting_OL1', 'y_starting_OL3', 'y_starting_OL4',
#        'y_starting_OL6', 'y_starting_OL7', 'y_starting_S0', 'y_starting_SS1',
#        'y_starting_SS2', 'y_starting_TE1'],
#       dtype='object', length=137)

# %%
cols_chosen = ['x', 'y', 'position_num', 'x_starting_behind_line',
               'y_starting', 'yardsToGo', 'yards_needed_touch', 'time_acc_s', 'yardline_first'] + week1_def_starting_cols

# %%
X_y = week1_off_starting[cols_chosen]

# %%
X = X_y.drop(['x', 'y'], axis=1)
y = X_y[['x', 'y']]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

impute = SimpleImputer(strategy="constant")
scaler = StandardScaler()
onehot = OneHotEncoder()

cat_cols = X_train.columns[X_train.dtypes == 'object']
num_cols = X_train.columns[X_train.dtypes != 'object']

cat_pipe = Pipeline([('one_hot', onehot)])
num_pipe = Pipeline([('impute', impute), ('scaler', scaler)])

full_pipe = ColumnTransformer([('cat', cat_pipe, cat_cols), ('num', num_pipe, num_cols)])
X_train_trans = full_pipe.fit_transform(X_train)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

lin_reg = LinearRegression()
cross_val_score(lin_reg, X_train_trans, y_train, cv=5, scoring='r2')
# Out:
# array([0.48016271, 0.47989667, 0.47978325, 0.48137025, 0.47803811])

# %%
from sklearn.tree import DecisionTreeRegressor

dtree = DecisionTreeRegressor(random_state=0)
cross_val_score(dtree, X_train_trans, y_train, cv=5, scoring='r2')
# Out:
# array([0.99373808, 0.99310472, 0.99325725, 0.99344381, 0.99261938])

# %%
from sklearn.model_selection import GridSearchCV

params = {'min_samples_split': range(2, 11)}
grid_dtree_x = GridSearchCV(dtree, params, cv=5, scoring='r2')
grid_dtree_x.fit(X_train_trans, y_train)

# %%
grid_dtree_x.best_score_
# Out:
# 0.9964318038312744

# %%
X_test_trans = full_pipe.transform(X_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

y_pred = grid_dtree_x.predict(X_test_trans)
rmse = mean_squared_error(y_test, y_pred) ** 0.5
print('RMSE:' , rmse)
mae = mean_absolute_error(y_test, y_pred)
print('MAE:', mae)
r2 = r2_score(y_test, y_pred)
print('R2:', r2)
# Out:
# RMSE: 1.4554549118404627
# MAE: 0.43122031974810415
# R2: 0.9966078135935623

# %%
y_train_y = y_train.iloc[:, 1]
y_test_y = y_test.iloc[:, 1]

# %%
dtree_y = DecisionTreeRegressor(random_state=0)
cross_val_score(dtree_y, X_train_trans, y_train_y, cv=5)
# Out:
# array([0.99064576, 0.98997035, 0.98975131, 0.98952702, 0.98950014])

# %%
lin_reg_y = LinearRegression()
cross_val_score(lin_reg_y, X_train_trans, y_train_y, cv=5)
# Out:
# array([0.09757562, 0.1000148 , 0.0962663 , 0.09981098, 0.09285922])

# %%
grid_dtree_y = GridSearchCV(dtree_y, params, cv=5, scoring='r2')
grid_dtree_y.fit(X_train_trans, y_train_y)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=0),
#              param_grid={'min_samples_split': range(2, 11)}, scoring='r2')

# %%
grid_dtree_y.best_score_
# Out:
# 0.7198346870470026

# %%
grid_dtree_y.best_params_
# Out:
# {'min_samples_split': 10}

# %%
params2 = {'min_samples_split': range(10, 21)}
grid_dtree_y2 = GridSearchCV(dtree_y, params2, cv=5, scoring='r2')
grid_dtree_y2.fit(X_train_trans, y_train_y)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=0),
#              param_grid={'min_samples_split': range(10, 21)}, scoring='r2')

# %%
grid_dtree_y2.best_score_
# Out:
# 0.7610923550346148

# %%
grid_dtree_y2.best_params_
# Out:
# {'min_samples_split': 20}

# %%
params3 = {'min_samples_split': range(20, 41, 2)}
grid_dtree_y3 = GridSearchCV(dtree_y, params3, cv=5, scoring='r2')
grid_dtree_y3.fit(X_train_trans, y_train_y)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=0),
#              param_grid={'min_samples_split': range(20, 41, 2)}, scoring='r2')

# %%
grid_dtree_y3.best_params_
# Out:
# {'min_samples_split': 34}

# %%
grid_dtree_y3.best_score_
# Out:
# 0.7717880338095024

# %%
best_model_x = grid_dtree_x
best_model_y = grid_dtree_y3

# %%
y_pred_y = best_model_y.predict(X_test_trans)
rmse_y = mean_squared_error(y_test_y, y_pred_y) ** 0.5
print('RMSE:' , rmse_y)
mae_y = mean_absolute_error(y_test_y, y_pred_y)
print('MAE:', mae_y)
r2_y = r2_score(y_test_y, y_pred_y)
print('R2:', r2_y)
# Out:
# RMSE: 5.534329742421087
# MAE: 2.662524747472196
# R2: 0.7755224685845884

# %%
plays = week1_off_starting[cols_chosen + ['playId', 'gameId', 'yardline_100']]

# %%
play1 = plays[plays['playId'] == plays['playId'].min()]

# %%
X_play1 = play1.drop(['x', 'y', 'playId', 'gameId'], axis=1)
y_play1_x = play1['x']

# %%
X_trans_play1 = full_pipe.transform(X_play1)

# %%
play1['x_pred'] = best_model_x.predict(X_trans_play1)
play1['y_pred'] = best_model_y.predict(X_trans_play1)
# Out:
# /var/folders/6v/8jcf0jcn7_vfm2q2r4tz44gh0000gn/T/ipykernel_91329/403026342.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   play1['x_pred'] = best_model_x.predict(X_trans_play1)
# /var/folders/6v/8jcf0jcn7_vfm2q2r4tz44gh0000gn/T/ipykernel_91329/403026342.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   play1['y_pred'] = best_model_y.predict(X_trans_play1)

# %%
play1_pred = play1[['x', 'y', 'position_num', 'x_pred', 'y_pred', 'yardline_first', 'yardline_100']]

# %%
chart1 = alt.Chart(play1_pred).encode(x=alt.X('x:Q'), y=alt.Y('y'), color=alt.Color('position_num')).mark_line()

# %%
chart1
# Out:
# alt.Chart(...)

# %%
import statsmodels.api as sm

endog_x = y_train.iloc[:, 0]
exog_x = X_train_trans
mod_x = sm.OLS(endog_x, exog_x)
results_x = mod_x.fit()
print(results_x.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      x   R-squared:                       0.858
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                 3.934e+04
# Date:                Fri, 25 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:37:06   Log-Likelihood:            -1.1011e+06
# No. Observations:              300744   AIC:                         2.202e+06
# Df Residuals:                  300697   BIC:                         2.203e+06
# Df Model:                          46
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            58.7784      1.390     42.283      0.000      56.054      61.503
# x2            60.5873      0.207    293.090      0.000      60.182      60.992
# x3            58.4707      0.245    239.059      0.000      57.991      58.950
# x4            58.7668      0.046   1275.984      0.000      58.677      58.857
# x5            58.8827      0.051   1155.082      0.000      58.783      58.983
# x6            58.7360      0.039   1492.542      0.000      58.659      58.813
# x7            59.1222      0.029   2045.217      0.000      59.066      59.179
# x8            -0.1211      0.026     -4.739      0.000      -0.171      -0.071
# x9             0.0218      0.017      1.257      0.209      -0.012       0.056
# x10            5.4474      0.065     84.030      0.000       5.320       5.574
# x11          -26.8114      0.370    -72.413      0.000     -27.537     -26.086
# x12            0.3625      0.018     19.713      0.000       0.326       0.399
# x13           33.1436      0.398     83.190      0.000      32.363      33.924
# x14           15.6936      0.071    221.616      0.000      15.555      15.832
# x15           -0.1077      0.039     -2.773      0.006      -0.184      -0.032
# x16           -0.4023      0.057     -7.039      0.000      -0.514      -0.290
# x17            0.2197      0.080      2.752      0.006       0.063       0.376
# x18            0.2479      0.041      6.031      0.000       0.167       0.328
# x19            0.3005      0.055      5.491      0.000       0.193       0.408
# x20            0.0058      0.049      0.120      0.905      -0.090       0.102
# x21            0.3799      0.050      7.528      0.000       0.281       0.479
# x22            0.0190      0.006      3.297      0.001       0.008       0.030
# x23            1.0756      0.040     27.018      0.000       0.998       1.154
# x24            0.0815      0.042      1.959      0.050   -4.55e-05       0.163
# x25            0.4818      0.040     12.155      0.000       0.404       0.560
# x26           -0.1729      0.009    -19.463      0.000      -0.190      -0.156
# x27            0.2271      0.023      9.947      0.000       0.182       0.272
# x28            0.4376      0.030     14.749      0.000       0.379       0.496
# x29           -0.2017      0.032     -6.278      0.000      -0.265      -0.139
# x30            0.0006      0.081      0.008      0.994      -0.158       0.159
# x31            0.6190      0.029     21.107      0.000       0.562       0.677
# x32            0.1997      0.032      6.293      0.000       0.137       0.262
# x33           -0.0109      0.032     -0.342      0.733      -0.073       0.052
# x34            0.0838      0.034      2.475      0.013       0.017       0.150
# x35           -0.0190      0.006     -3.297      0.001      -0.030      -0.008
# x36            0.0811      0.022      3.715      0.000       0.038       0.124
# x37           -0.4979      0.049    -10.114      0.000      -0.594      -0.401
# x38            0.1563      0.026      6.033      0.000       0.105       0.207
# x39            0.1729      0.009     19.463      0.000       0.156       0.190
# x40           -0.3016      0.018    -16.516      0.000      -0.337      -0.266
# x41            0.3362      0.036      9.235      0.000       0.265       0.408
# x42            0.1504      0.025      6.060      0.000       0.102       0.199
# x43           -0.2460      0.095     -2.595      0.009      -0.432      -0.060
# x44            0.2522      0.034      7.526      0.000       0.186       0.318
# x45            0.3898      0.051      7.589      0.000       0.289       0.490
# x46            0.2348      0.050      4.674      0.000       0.136       0.333
# x47            0.1757      0.054      3.270      0.001       0.070       0.281
# x48            0.0190      0.006      3.297      0.001       0.008       0.030
# x49           -0.3865      0.029    -13.155      0.000      -0.444      -0.329
# x50           -0.8705      0.055    -15.963      0.000      -0.977      -0.764
# x51           -0.1218      0.034     -3.621      0.000      -0.188      -0.056
# x52           -0.1729      0.009    -19.463      0.000      -0.190      -0.156
# ==============================================================================
# Omnibus:                    20806.604   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            86932.836
# Skew:                           0.224   Prob(JB):                         0.00
# Kurtosis:                       5.595   Cond. No.                     1.60e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.63e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
endog_y = y_train.iloc[:, 1]
exog_y = X_train_trans
mod_y = sm.OLS(endog_y, exog_y)
results_y = mod_y.fit()
print(results_y.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.099
# Model:                            OLS   Adj. R-squared:                  0.099
# Method:                 Least Squares   F-statistic:                     612.4
# Date:                Fri, 25 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:32:37   Log-Likelihood:            -1.1494e+06
# No. Observations:              300744   AIC:                         2.299e+06
# Df Residuals:                  300689   BIC:                         2.300e+06
# Df Model:                          54
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1         -4.103e+12   1.61e+12     -2.548      0.011   -7.26e+12   -9.46e+11
# x2         -4.103e+12   1.61e+12     -2.548      0.011   -7.26e+12   -9.46e+11
# x3         -4.103e+12   1.61e+12     -2.548      0.011   -7.26e+12   -9.46e+11
# x4         -4.103e+12   1.61e+12     -2.548      0.011   -7.26e+12   -9.46e+11
# x5         -4.103e+12   1.61e+12     -2.548      0.011   -7.26e+12   -9.46e+11
# x6         -4.103e+12   1.61e+12     -2.548      0.011   -7.26e+12   -9.46e+11
# x7         -4.103e+12   1.61e+12     -2.548      0.011   -7.26e+12   -9.46e+11
# x8          4.103e+12   1.61e+12      2.548      0.011    9.46e+11    7.26e+12
# x9          4.103e+12   1.61e+12      2.548      0.011    9.46e+11    7.26e+12
# x10         4.103e+12   1.61e+12      2.548      0.011    9.46e+11    7.26e+12
# x11         4.103e+12   1.61e+12      2.548      0.011    9.46e+11    7.26e+12
# x12         4.103e+12   1.61e+12      2.548      0.011    9.46e+11    7.26e+12
# x13         4.103e+12   1.61e+12      2.548      0.011    9.46e+11    7.26e+12
# x14         4.103e+12   1.61e+12      2.548      0.011    9.46e+11    7.26e+12
# x15         4.103e+12   1.61e+12      2.548      0.011    9.46e+11    7.26e+12
# x16           -0.4352      0.086     -5.054      0.000      -0.604      -0.266
# x17           -0.1844      0.030     -6.079      0.000      -0.244      -0.125
# x18            3.5491      0.020    174.223      0.000       3.509       3.589
# x19            0.4971      0.087      5.687      0.000       0.326       0.668
# x20           -2.4401      0.489     -4.988      0.000      -3.399      -1.481
# x21            0.4015      0.022     18.303      0.000       0.358       0.444
# x22            2.6379      0.538      4.901      0.000       1.583       3.693
# x23            1.3927      0.093     14.896      0.000       1.209       1.576
# x24            0.1509      0.046      3.298      0.001       0.061       0.241
# x25        -4.339e+10    1.7e+10     -2.548      0.011   -7.68e+10      -1e+10
# x26            0.5612      0.094      5.978      0.000       0.377       0.745
# x27           -0.9358      0.050    -18.828      0.000      -1.033      -0.838
# x28           -0.5817      0.065     -8.980      0.000      -0.709      -0.455
# x29            0.0565      0.058      0.974      0.330      -0.057       0.170
# x30           -0.6568      0.060    -10.991      0.000      -0.774      -0.540
# x31         2.421e+12    9.5e+11      2.548      0.011    5.58e+11    4.28e+12
# x32            0.1608      0.048      3.366      0.001       0.067       0.254
# x33           -0.0331      0.049     -0.672      0.502      -0.130       0.064
# x34           -0.8614      0.047    -18.384      0.000      -0.953      -0.770
# x35        -2.546e+11   9.99e+10     -2.548      0.011    -4.5e+11   -5.87e+10
# x36           -0.0557      0.027     -2.070      0.038      -0.108      -0.003
# x37           -0.0337      0.035     -0.964      0.335      -0.102       0.035
# x38         4.622e+11   1.81e+11      2.548      0.011    1.07e+11    8.18e+11
# x39           -0.1235      0.095     -1.299      0.194      -0.310       0.063
# x40           -0.0745      0.035     -2.131      0.033      -0.143      -0.006
# x41            0.2159      0.038      5.742      0.000       0.142       0.290
# x42            0.0502      0.038      1.335      0.182      -0.024       0.124
# x43            0.2103      0.040      5.265      0.000       0.132       0.289
# x44         1.276e+12   5.01e+11      2.548      0.011    2.94e+11    2.26e+12
# x45           -0.0427      0.026     -1.657      0.098      -0.093       0.008
# x46           -0.2500      0.058     -4.292      0.000      -0.364      -0.136
# x47           -0.0322      0.031     -1.045      0.296      -0.093       0.028
# x48         2.983e+11   1.17e+11      2.548      0.011    6.88e+10    5.28e+11
# x49           -0.0517      0.022     -2.382      0.017      -0.094      -0.009
# x50           -0.3262      0.043     -7.578      0.000      -0.411      -0.242
# x51         5.035e+11   1.98e+11      2.548      0.011    1.16e+11    8.91e+11
# x52           -0.7732      0.111     -6.941      0.000      -0.992      -0.555
# x53            0.9450      0.041     23.222      0.000       0.865       1.025
# x54            0.6776      0.061     11.124      0.000       0.558       0.797
# x55            0.0205      0.060      0.344      0.731      -0.096       0.137
# x56            0.9055      0.064     14.250      0.000       0.781       1.030
# x57        -1.144e+12   4.49e+11     -2.548      0.011   -2.02e+12   -2.64e+11
# x58           -0.1283      0.035     -3.669      0.000      -0.197      -0.060
# x59           -0.0074      0.064     -0.115      0.909      -0.133       0.119
# x60            0.5090      0.040     12.813      0.000       0.431       0.587
# x61         5.529e+11   2.17e+11      2.548      0.011    1.28e+11    9.78e+11
# ==============================================================================
# Omnibus:                       21.180   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.906
# Skew:                          -0.014   Prob(JB):                     2.89e-05
# Kurtosis:                       2.971   Cond. No.                     1.52e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.84e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
y_pred_x = results_x.predict(X_test_trans)
y_test_x = y_test.iloc[:, 0]

# %%
rmse_x = mean_squared_error(y_test_x, y_pred_x) ** 0.5
mae_x = mean_absolute_error(y_test_x, y_pred_x)
print("RMSE for x model:", rmse_x)
print("MAE for x model:", mae_x)
# Out:
# RMSE for x model: 8.808742911843032
# MAE for x model: 6.2646044077173695

# %%
y_pred_y = results_y.predict(X_test_trans)
y_test_y = y_test.iloc[:, 1]

# %%
rmse_y = mean_squared_error(y_test_y, y_pred_y) ** 0.5
mae_y = mean_absolute_error(y_test_y, y_pred_y)
print("RMSE for y model:", rmse_y)
print("MAE for y model:", mae_y)
# Out:
# RMSE for y model: 11.121118954063988
# MAE for y model: 8.543724992188883

# %%
ci_results_x = results_x.conf_int(0.1)

# %%
ci_results_linspace = ci_results_x.apply(lambda x: np.linspace(x[0], x[1], 10), axis=1).explode()

# %%
idx_part = (ci_results_linspace
 .groupby(ci_results_linspace.index)
 .apply(lambda x: range(x.shape[0]))
 .explode().rename({'data': 'idx_part'}, axis=1))
ci_results_linspace = ci_results_linspace.reset_index()

# %%
ci_results_linspace['idx_part'] = idx_part.values

# %%
ci_results_linspace.rename({0: 'param_val'}, axis=1, inplace=True)
ci_results_linspace = ci_results_linspace.pivot_table(columns='idx_part', values='param_val', index='index')

# %%
ci_results_linspace['idx'] = ci_results_linspace.index.str.extract('(\d+)').astype(int).values
ci_results_linspace = ci_results_linspace.sort_values('idx').drop('idx', axis=1)

# %%
result_range = X_test_trans @ ci_results_linspace

# %%
result_range
# Out:
# idx_part             0             1             2             3  \
# 0        -4.152091e+12 -3.229404e+12 -2.306717e+12 -1.384030e+12
# 1        -4.152091e+12 -3.229404e+12 -2.306717e+12 -1.384030e+12
# 2        -4.152091e+12 -3.229404e+12 -2.306717e+12 -1.384030e+12
# 3        -4.152091e+12 -3.229404e+12 -2.306717e+12 -1.384030e+12
# 4        -4.152091e+12 -3.229404e+12 -2.306717e+12 -1.384030e+12
# ...                ...           ...           ...           ...
# 100244   -4.152091e+12 -3.229404e+12 -2.306717e+12 -1.384030e+12
# 100245   -4.152091e+12 -3.229404e+12 -2.306717e+12 -1.384030e+12
# 100246   -4.152091e+12 -3.229404e+12 -2.306717e+12 -1.384030e+12
# 100247   -4.152091e+12 -3.229404e+12 -2.306717e+12 -1.384030e+12
# 100248   -4.152091e+12 -3.229404e+12 -2.306717e+12 -1.384030e+12
#
# idx_part             4             5             6             7  \
# 0        -4.613434e+11  4.613434e+11  1.384030e+12  2.306717e+12
# 1        -4.613434e+11  4.613434e+11  1.384030e+12  2.306717e+12
# 2        -4.613434e+11  4.613434e+11  1.384030e+12  2.306717e+12
# 3        -4.613434e+11  4.613434e+11  1.384030e+12  2.306717e+12
# 4        -4.613434e+11  4.613434e+11  1.384030e+12  2.306717e+12
# ...                ...           ...           ...           ...
# 100244   -4.613434e+11  4.613434e+11  1.384030e+12  2.306717e+12
# 100245   -4.613434e+11  4.613434e+11  1.384030e+12  2.306717e+12
# 100246   -4.613434e+11  4.613434e+11  1.384030e+12  2.306717e+12
# 100247   -4.613434e+11  4.613434e+11  1.384030e+12  2.306717e+12
# 100248   -4.613434e+11  4.613434e+11  1.384030e+12  2.306717e+12
#
# idx_part             8             9
# 0         3.229404e+12  4.152091e+12
# 1         3.229404e+12  4.152091e+12
# 2         3.229404e+12  4.152091e+12
# 3         3.229404e+12  4.152091e+12
# 4         3.229404e+12  4.152091e+12
# ...                ...           ...
# 100244    3.229404e+12  4.152091e+12
# 100245    3.229404e+12  4.152091e+12
# 100246    3.229404e+12  4.152091e+12
# 100247    3.229404e+12  4.152091e+12
# 100248    3.229404e+12  4.152091e+12
#
# [100249 rows x 10 columns]

# %%
results_x.conf_int(0.05)
# Out:
#              0          1
# x1   58.585366  63.655791
# x2   60.088821  60.842807
# x3   58.358905  59.251027
# x4   58.821125  58.989128
# x5   59.009803  59.195778
# x6   58.510172  58.653734
# x7   59.004780  59.110223
# x8   14.513444  14.779341
# x9    0.050930   0.144205
# x10  -0.135939  -0.072720
# x11  -1.835840  -1.566122
# x12   9.368475  10.876228
# x13   0.176501   0.243635
# x14 -11.901355 -10.241245
# x15   8.598284   8.885754
# x16   0.015496   0.157124
# x17  -0.779381  -0.570866
# x18  -0.474370  -0.182937
# x19   1.881961   2.035068
# x20  -0.369789  -0.169892
# x21   0.229198   0.407557
# x22   0.419440   0.603498
# x23  -0.023589  -0.002513
# x24  -0.506076  -0.358311
# x25   0.990714   1.143445
# x26   0.906700   1.051562
# x27  -0.031047   0.001486
# x28   0.204091   0.287362
# x29   0.359984   0.468197
# x30  -0.346830  -0.229666
# x31  -0.023579   0.271608
# x32   0.399315   0.506333
# x33   0.136711   0.252431
# x34  -0.152241  -0.036124
# x35  -0.239205  -0.115618
# x36   0.002513   0.023589
# x37   0.016670   0.096340
# x38   0.350339   0.530689
# x39   0.216219   0.310718
# x40  -0.001486   0.031047
# x41   0.085261   0.152300
# x42   0.458824   0.591648
# x43   0.161120   0.251678
# x44   0.151480   0.497363
# x45  -1.353584  -1.228196
# x46   0.787540   0.975082
# x47  -0.202987  -0.019610
# x48  -0.433441  -0.237272
# x49  -0.023589  -0.002513
# x50   0.411892   0.520171
# x51  -0.934157  -0.735264
# x52  -0.697701  -0.574678
# x53  -0.031047   0.001486

# %%
ci_results_linspace
# Out:
# idx_part          0          1          2          3          4          5  \
# index
# x1        58.992963  59.465767  59.938570  60.411374  60.884177  61.356980
# x10       -0.130857  -0.124962  -0.119067  -0.113172  -0.107277  -0.101382
# x11       -1.814158  -1.789007  -1.763857  -1.738706  -1.713556  -1.688405
# x12        9.489679   9.630273   9.770867   9.911461  10.052054  10.192648
# x13        0.181897   0.188157   0.194418   0.200678   0.206938   0.213198
# x14      -11.767903 -11.613103 -11.458302 -11.303501 -11.148700 -10.993900
# x15        8.621393   8.648199   8.675004   8.701810   8.728616   8.755422
# x16        0.026881   0.040087   0.053294   0.066500   0.079707   0.092913
# x17       -0.762619  -0.743176  -0.723732  -0.704289  -0.684845  -0.665402
# x18       -0.450942  -0.423767  -0.396592  -0.369416  -0.342241  -0.315065
# x19        1.894269   1.908546   1.922823   1.937099   1.951376   1.965653
# x2        60.149431  60.219739  60.290046  60.360353  60.430660  60.500968
# x20       -0.353720  -0.335080  -0.316440  -0.297800  -0.279160  -0.260521
# x21        0.243536   0.260168   0.276799   0.293431   0.310062   0.326694
# x22        0.434236   0.451399   0.468562   0.485725   0.502888   0.520050
# x23       -0.021895  -0.019930  -0.017964  -0.015999  -0.014034  -0.012068
# x24       -0.494198  -0.480419  -0.466640  -0.452862  -0.439083  -0.425304
# x25        1.002992   1.017234   1.031475   1.045717   1.059959   1.074201
# x26        0.918345   0.931853   0.945361   0.958869   0.972377   0.985885
# x27       -0.028432  -0.025398  -0.022364  -0.019331  -0.016297  -0.013264
# x28        0.210785   0.218550   0.226315   0.234079   0.241844   0.249609
# x29        0.368683   0.378774   0.388864   0.398955   0.409045   0.419136
# x3        58.430620  58.513808  58.596996  58.680184  58.763372  58.846560
# x30       -0.337412  -0.326486  -0.315561  -0.304636  -0.293711  -0.282786
# x31        0.000150   0.027675   0.055201   0.082726   0.110252   0.137777
# x32        0.407918   0.417897   0.427876   0.437855   0.447834   0.457813
# x33        0.146013   0.156804   0.167594   0.178385   0.189175   0.199966
# x34       -0.142906  -0.132079  -0.121251  -0.110424  -0.099596  -0.088769
# x35       -0.229270  -0.217746  -0.206222  -0.194697  -0.183173  -0.171649
# x36        0.004207   0.006173   0.008138   0.010103   0.012068   0.014034
# x37        0.023074   0.030503   0.037933   0.045362   0.052791   0.060220
# x38        0.364837   0.381654   0.398471   0.415288   0.432105   0.448922
# x39        0.223816   0.232627   0.241439   0.250251   0.259063   0.267874
# x4        58.834631  58.850297  58.865962  58.881628  58.897294  58.912960
# x40        0.001129   0.004163   0.007196   0.010230   0.013264   0.016297
# x41        0.090650   0.096901   0.103153   0.109404   0.115655   0.121906
# x42        0.469501   0.481887   0.494272   0.506658   0.519043   0.531429
# x43        0.168400   0.176844   0.185288   0.193733   0.202177   0.210621
# x44        0.179284   0.211537   0.243790   0.276042   0.308295   0.340548
# x45       -1.343505  -1.331812  -1.320120  -1.308428  -1.296736  -1.285044
# x46        0.802616   0.820103   0.837591   0.855079   0.872567   0.890055
# x47       -0.188246  -0.171146  -0.154047  -0.136947  -0.119848  -0.102749
# x48       -0.417672  -0.399380  -0.381087  -0.362795  -0.344503  -0.326211
# x49       -0.021895  -0.019930  -0.017964  -0.015999  -0.014034  -0.012068
# x5        59.024753  59.042094  59.059436  59.076778  59.094119  59.111461
# x50        0.420596   0.430693   0.440790   0.450887   0.460983   0.471080
# x51       -0.918168  -0.899622  -0.881076  -0.862530  -0.843983  -0.825437
# x52       -0.687812  -0.676340  -0.664869  -0.653397  -0.641925  -0.630454
# x53       -0.028432  -0.025398  -0.022364  -0.019331  -0.016297  -0.013264
# x6        58.521712  58.535099  58.548486  58.561873  58.575260  58.588646
# x7        59.013257  59.023089  59.032921  59.042753  59.052586  59.062418
# x8        14.534819  14.559613  14.584407  14.609201  14.633995  14.658789
# x9         0.058428   0.067126   0.075824   0.084521   0.093219   0.101916
#
# idx_part          6          7          8          9
# index
# x1        61.829784  62.302587  62.775391  63.248194
# x10       -0.095487  -0.089592  -0.083697  -0.077802
# x11       -1.663255  -1.638104  -1.612954  -1.587804
# x12       10.333242  10.473836  10.614430  10.755024
# x13        0.219458   0.225718   0.231978   0.238239
# x14      -10.839099 -10.684298 -10.529498 -10.374697
# x15        8.782228   8.809034   8.835840   8.862645
# x16        0.106120   0.119326   0.132533   0.145739
# x17       -0.645958  -0.626515  -0.607071  -0.587628
# x18       -0.287890  -0.260715  -0.233539  -0.206364
# x19        1.979930   1.994207   2.008484   2.022761
# x2        60.571275  60.641582  60.711889  60.782197
# x20       -0.241881  -0.223241  -0.204601  -0.185961
# x21        0.343325   0.359957   0.376588   0.393220
# x22        0.537213   0.554376   0.571539   0.588702
# x23       -0.010103  -0.008138  -0.006173  -0.004207
# x24       -0.411526  -0.397747  -0.383968  -0.370190
# x25        1.088442   1.102684   1.116926   1.131168
# x26        0.999393   1.012901   1.026409   1.039917
# x27       -0.010230  -0.007196  -0.004163  -0.001129
# x28        0.257374   0.265138   0.272903   0.280668
# x29        0.429227   0.439317   0.449408   0.459498
# x3        58.929748  59.012936  59.096124  59.179312
# x30       -0.271860  -0.260935  -0.250010  -0.239085
# x31        0.165303   0.192828   0.220353   0.247879
# x32        0.467792   0.477771   0.487751   0.497730
# x33        0.210757   0.221547   0.232338   0.243128
# x34       -0.077941  -0.067114  -0.056286  -0.045459
# x35       -0.160125  -0.148601  -0.137077  -0.125552
# x36        0.015999   0.017964   0.019930   0.021895
# x37        0.067649   0.075078   0.082507   0.089936
# x38        0.465740   0.482557   0.499374   0.516191
# x39        0.276686   0.285498   0.294310   0.303121
# x4        58.928625  58.944291  58.959957  58.975623
# x40        0.019331   0.022364   0.025398   0.028432
# x41        0.128157   0.134408   0.140659   0.146911
# x42        0.543814   0.556200   0.568585   0.580971
# x43        0.219066   0.227510   0.235954   0.244398
# x44        0.372800   0.405053   0.437306   0.469558
# x45       -1.273352  -1.261660  -1.249968  -1.238276
# x46        0.907542   0.925030   0.942518   0.960006
# x47       -0.085649  -0.068550  -0.051450  -0.034351
# x48       -0.307918  -0.289626  -0.271334  -0.253042
# x49       -0.010103  -0.008138  -0.006173  -0.004207
# x5        59.128803  59.146144  59.163486  59.180828
# x50        0.481177   0.491274   0.501370   0.511467
# x51       -0.806891  -0.788345  -0.769798  -0.751252
# x52       -0.618982  -0.607510  -0.596039  -0.584567
# x53       -0.010230  -0.007196  -0.004163  -0.001129
# x6        58.602033  58.615420  58.628807  58.642194
# x7        59.072250  59.082083  59.091915  59.101747
# x8        14.683584  14.708378  14.733172  14.757966
# x9         0.110614   0.119312   0.128009   0.136707

# %%
X_test_trans @ results_x.conf_int(alpha=0.05)
# Out:
#                 0          1
# 0       51.404999  51.656685
# 1       86.063966  90.768407
# 2       40.110251  36.945019
# 3       51.995652  51.755175
# 4       78.041109  82.180387
# ...           ...        ...
# 100244  41.760524  38.276722
# 100245  34.900764  31.909587
# 100246  25.043493  19.771509
# 100247  26.506075  21.984185
# 100248  78.002254  81.313846
#
# [100249 rows x 2 columns]
